# %%
# Packages einlesen
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
import json
import pandas as pd

# Initialize an empty list to store parsed JSON data
data = []

# Open the JSON Lines file
with open('/Users/paulahofmann/Desktop/meta_Beauty_and_Personal_Care.jsonl', 'r') as file:
    # Read each line from the file
    for line in file:
        # Parse the JSON data from the line
        line_data = json.loads(line)
        # Append the parsed data to the list
        data.append(line_data)

# Create a DataFrame from the list of parsed data
df = pd.DataFrame(data)

# %%
# Sort the DataFrame by 'rating_number' column in descending order
df_sorted = df.sort_values(by='rating_number', ascending=False)

# Select the top 200 rows
top_200_products = df_sorted.head(200)

# Display the top 200 products
print(top_200_products)
# Out:
#                   main_category  \
# 570727               All Beauty
# 759164               All Beauty
# 941783                     None
# 304180               All Beauty
# 824385                     None
# ...                         ...
# 287588           Premium Beauty
# 320261               All Beauty
# 758468               All Beauty
# 820919  Industrial & Scientific
# 4368                 All Beauty
#
#                                                     title  average_rating  \
# 570727  essence | Lash Princess False Lash Effect Masc...             4.3
# 759164  REVLON One-Step Volumizer Original 1.0 Hair Dr...             4.6
# 941783  Maybelline New York Instant Age Rewind Eraser ...             4.4
# 304180  Schick Hydro Silk Touch-Up Exfoliating Dermapl...             4.6
# 824385  Philips Norelco Multigroomer All-in-One Trimme...             4.5
# ...                                                   ...             ...
# 287588  OPI Nail Lacquer, Violet Visionary, Purple Nai...             4.6
# 320261  Beetles 20 Pcs Gel Nail Polish Kit, Animal Pri...             4.5
# 758468  Biotique Bio Cucumber Pore Tightening Toner wi...             4.1
# 820919  623181 Q-Tips Cotton Swab, Standard, White, 50...             4.8
# 4368    Degree Men Antiperspirant Deodorant 48-Hour Od...             4.7
#
#         rating_number                                           features  \
# 570727         340182  [If you receive this mascara UNWRAPPED, it did...
# 759164         335286  [This product is non-sealed, STYLE AND DRY IN ...
# 941783         194141  [Maybelline Instant Age Rewind Concealer: Amer...
# 304180         181406  [Quick, Easy Touch-Ups – Schick Hydro Silk Tou...
# 824385         152647  [13 attachments for all of your grooming needs...
# ...               ...                                                ...
# 287588          44755                                                 []
# 320261          44663  [【What You Get】: 20 x Mini Gel Polish Colors (...
# 758468          44551  [Helps reduce the risk of skin aging and other...
# 820919          44516  [100 percent pure cotton, Firm, but flexible p...
# 4368            44483  [Degree’s Cool Rush antiperspirant deodorant w...
#
#                                               description  price  \
# 570727                                                 []   4.99
# 759164  [The Revlon One-Step Volumizer 1.0 Original is...   38.8
# 941783  [Say goodbye to dark circles with Maybelline N...   7.53
# 304180  [Look your best at a moment's notice! Whether ...  17.39
# 824385  [The Philips Norelco Multigroom 3000 is a all-...  21.96
# ...                                                   ...    ...
# 287588                                                 []  11.49
# 320261                                                 []  31.99
# 758468                                                 []    9.0
# 820919  [SC Johnson 623181 Q-Tip Cotton Swab, Standard...   None
# 4368    [Degree Cool Rush helps keep you fresh and dry...  11.98
#
#                                                    images  \
# 570727  [{'thumb': 'https://m.media-amazon.com/images/...
# 759164  [{'thumb': 'https://m.media-amazon.com/images/...
# 941783  [{'thumb': 'https://m.media-amazon.com/images/...
# 304180  [{'thumb': 'https://m.media-amazon.com/images/...
# 824385  [{'thumb': 'https://m.media-amazon.com/images/...
# ...                                                   ...
# 287588  [{'thumb': 'https://m.media-amazon.com/images/...
# 320261  [{'thumb': 'https://m.media-amazon.com/images/...
# 758468  [{'thumb': 'https://m.media-amazon.com/images/...
# 820919  [{'thumb': 'https://m.media-amazon.com/images/...
# 4368    [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                                    videos               store  \
# 570727  [{'title': 'HONEST Review of the ESSENCE Masca...   essence cosmetics
# 759164  [{'title': 'Compare Revlon Hot Air Brush 1.0 a...              REVLON
# 941783                                                 []          MAYBELLINE
# 304180  [{'title': 'Face shaving 101...', 'url': 'http...   Schick Hydro Silk
# 824385                                                 []             PHILIPS
# ...                                                   ...                 ...
# 287588  [{'title': 'OPI DTLA - Fall 2021 Collection', ...                None
# 320261  [{'title': 'My honest review on the Bettles Ge...  beetles Gel Polish
# 758468  [{'title': 'Biotique Bio Cucumber Pore Tighten...            Biotique
# 820919                                                 []              Q-tips
# 4368    [{'title': 'Different design from what's shown...              DEGREE
#
#                                                categories  \
# 570727    [Beauty & Personal Care, Makeup, Eyes, Mascara]
# 759164  [Beauty & Personal Care, Hair Care, Styling To...
# 941783  [Beauty & Personal Care, Makeup, Face, Conceal...
# 304180  [Beauty & Personal Care, Shave & Hair Removal,...
# 824385  [Beauty & Personal Care, Shave & Hair Removal,...
# ...                                                   ...
# 287588  [Beauty & Personal Care, Salon & Spa, Foot, Ha...
# 320261  [Beauty & Personal Care, Foot, Hand & Nail Car...
# 758468  [Beauty & Personal Care, Skin Care, Face, Tone...
# 820919  [Beauty & Personal Care, Tools & Accessories, ...
# 4368    [Beauty & Personal Care, Personal Care, Deodor...
#
#                                                   details parent_asin  \
# 570727  {'Color': 'False Lash Effect', 'Product Benefi...  B0BVGHXZJ1
# 759164  {'Brand': 'REVLON', 'Color': 'Black', 'Materia...  B01LSUQSB0
# 941783  {'Product Dimensions': '0.81 x 1.88 x 5.63 inc...  B0C47HXVSJ
# 304180  {'Brand': 'Schick Hydro Silk', 'Number of Blad...  B0BHMQLLR4
# 824385  {'Recommended Uses For Product': 'Face, Beard,...  B01K1HPA60
# ...                                                   ...         ...
# 287588  {'Brand': 'OPI', 'Item Form': 'Liquid', 'Color...  B0C7MC1F7G
# 320261  {'Brand': 'beetles Gel Polish', 'Item Form': '...  B0BWNHQFGY
# 758468  {'Brand': 'Biotique', 'Item Form': 'Liquid', '...  B010E1UQI0
# 820919  {'Brand': 'Q-tips', 'Model Name': 'Cotton Swab...  B07GPP3XC1
# 4368    {'Brand': 'DEGREE', 'Item Form': 'Stick', 'Sce...  B093ZY9YDQ
#
#        bought_together subtitle author
# 570727            None      NaN    NaN
# 759164            None      NaN    NaN
# 941783            None      NaN    NaN
# 304180            None      NaN    NaN
# 824385            None      NaN    NaN
# ...                ...      ...    ...
# 287588            None      NaN    NaN
# 320261            None      NaN    NaN
# 758468            None      NaN    NaN
# 820919            None      NaN    NaN
# 4368              None      NaN    NaN
#
# [200 rows x 16 columns]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
